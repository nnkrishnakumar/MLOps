# %%
# import libraries

import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler,LabelEncoder

# %%
raw_train=pd.read_csv("archive/loan-train.csv")
raw_test=pd.read_csv("archive/loan-test.csv")

# %%
raw_train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# to get the row and column of the dataset
raw_train.shape
# Out:
# (614, 13)

# %%
# nuinque will provide unique value of the each column
raw_train.nunique()
# Out:
# Loan_ID              614
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
#creating copy of train data and test data to make original data intact

df_train=raw_train
df_test=raw_test

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
# create a copy of train_df and test_df
train_df=df_train.copy()
test_df=df_test.copy()

# %%
# info() method is used to get the information of each column
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
# Note: here in this table the last 12(Loan_Status) row is missing 
test_df.info()    # only for predicition
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
# creating a deep copy of Loan Status of training dataset.

train_y=train_df['Loan_Status'].copy()

# %%
train_y     # this is also called traget of trained dataset
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
# Now I will drop the column of train_y from train_df

train_df.drop(columns='Loan_Status',inplace=True)

# %%
train_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
train_df.shape  # successed to finally drop the last column of the train_df
# Out:
# (614, 12)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %%
# Dropping the column which is not important for our analysis

train_df.drop(columns='Loan_ID',inplace=True)

# %%
train_df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
# dropping the column which is not important for our analysis in test dataframe

test_df.drop(columns="Loan_ID",inplace=True)

# %%
test_df
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male     Yes          0      Graduate            No             5720
# 1     Male     Yes          1      Graduate            No             3076
# 2     Male     Yes          2      Graduate            No             5000
# 3     Male     Yes          2      Graduate            No             2340
# 4     Male      No          0  Not Graduate            No             3276
# ..     ...     ...        ...           ...           ...              ...
# 362   Male     Yes         3+  Not Graduate           Yes             4009
# 363   Male     Yes          0      Graduate            No             4158
# 364   Male      No          0      Graduate            No             3250
# 365   Male     Yes          0      Graduate            No             5000
# 366   Male      No          0      Graduate           Yes             9200
#
# ...

# %%
# to see the columns
train_df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
#duplcate value detection

train_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Length: 614, dtype: bool

# %%
# now i will pass train_df.duplicated() to check whether there is duplicate values or not

train_df[train_df.duplicated]    # None of the duplicat row exist there
# Out:
# Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area]
# Index: []

# %%
# Now check the duplicate row in the test data as well

test_df[test_df.duplicated]
# Out:
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 195   Male      No          0  Graduate           Yes             5833
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 195                  0       116.0             360.0             1.0
#
#     Property_Area
# 195         Urban

# %%
# now removing the duplicate row in the test dataframe beacause it doesnot make any sense

test_df.drop_duplicates(inplace=True)

# %%
test_df[test_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area]
# Index: []

# %%
# Missing value analyais

train_df.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
# filled up all the values to protect our data

# numerical value ====> with mean
# categoical value ====> with mode

# %%
train_df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
train_df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area
# 0         Urban
# 1         Rural
# 2         Urban
# 3         Urban
# 4         Urban

# %%
num_cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']
cat_cols=['Gender','Married','Dependents','Education','Self_Employed','Credit_History','Property_Area']

# %%
train_df.nunique()
# Out:
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# dtype: int64

# %%
# Now to fill the data with catagorical column 

cat_imputer=SimpleImputer(strategy="most_frequent")
cat_imputer.fit(train_df[cat_cols])
train_df[cat_cols]=cat_imputer.transform(train_df[cat_cols])
test_df[cat_cols]=cat_imputer.transform(test_df[cat_cols])

# %%
# Now to fill the data with numerical colum

num_imputer=SimpleImputer(strategy='mean')
num_imputer.fit(train_df[num_cols])
train_df[num_cols]=num_imputer.transform(train_df[num_cols])
test_df[num_cols]=num_imputer.transform(test_df[num_cols])

# %%
train_df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No           5849.0
# 1      Male     Yes          1      Graduate            No           4583.0
# 2      Male     Yes          0      Graduate           Yes           3000.0
# 3      Male     Yes          0  Not Graduate            No           2583.0
# 4      Male      No          0      Graduate            No           6000.0
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No           2900.0
# 610    Male     Yes         3+      Graduate            No           4106.0
# 611    Male     Yes          1      Graduate            No           8072.0
# 612    Male     Yes          2      Graduate            No           7583.0
# 613  Female      No          0      Graduate           Yes           4583.0
#
# ...

# %%
train_df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
# now lets add the income and coapplicant income in single column
train_df['ApplicantIncome']=train_df['ApplicantIncome']+train_df['CoapplicantIncome']
test_df['ApplicantIncome']=test_df['ApplicantIncome']+test_df['CoapplicantIncome']

# now drop the coapplicant income from training and testing dataframe
train_df.drop(columns='CoapplicantIncome',inplace=True)
train_df.drop(columns='CoapplicantIncome',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 7
#       5 # now drop the coapplicant income from training and testing dataframe
#       6 train_df.drop(columns='CoapplicantIncome',inplace=True)
# ----> 7 train_df.drop(columns='CoapplicantIncome',inplace=True)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
# ...

# %%
train_df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History',
#        'Property_Area'],
#       dtype='object')

# %%
train_df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No           5849.0
# 1      Male     Yes          1      Graduate            No           6091.0
# 2      Male     Yes          0      Graduate           Yes           3000.0
# 3      Male     Yes          0  Not Graduate            No           4941.0
# 4      Male      No          0      Graduate            No           6000.0
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No           2900.0
# 610    Male     Yes         3+      Graduate            No           4106.0
# 611    Male     Yes          1      Graduate            No           8312.0
# 612    Male     Yes          2      Graduate            No           7583.0
# 613  Female      No          0      Graduate           Yes           4583.0
#
# ...

# %%
for col in cat_cols:
    le=LabelEncoder()
    train_df[col]=le.fit_transform(train_df[col])
    test_df[col]=le.fit_transform(test_df[col])

# %%
train_df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0           5849.0
# 1         1        1           1          0              0           6091.0
# 2         1        1           0          0              1           3000.0
# 3         1        1           0          1              0           4941.0
# 4         1        0           0          0              0           6000.0
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0           2900.0
# 610       1        1           3          0              0           4106.0
# 611       1        1           1          0              0           8312.0
# 612       1        1           2          0              0           7583.0
# 613       0        0           0          0              1           4583.0
#
# ...

# %%
# Building the Model

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(train_df,train_y,test_size=0.3,random_state=42)

# %%
train_y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
X_train
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 553       1        1           0          1              0           4787.0
# 601       1        1           0          1              0           5686.0
# 261       1        0           0          0              0           4269.0
# 496       1        1           0          1              0           4300.0
# 529       1        0           0          1              0           6783.0
# ..      ...      ...         ...        ...            ...              ...
# 71        1        1           2          1              1           3750.0
# 106       1        1           2          0              0          12543.0
# 270       0        0           0          0              0           3237.0
# 435       0        1           0          0              0          10047.0
# 102       1        1           0          0              0          13650.0
#
# ...

# %%
y_train
# Out:
# 553    N
# 601    Y
# 261    Y
# 496    Y
# 529    Y
#       ..
# 71     Y
# 106    Y
# 270    Y
# 435    Y
# 102    Y
# Name: Loan_Status, Length: 429, dtype: object

# %%
X_test
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 350       1        1           0          0              0           9083.0
# 377       1        1           0          0              0           4310.0
# 163       1        1           2          0              0           5614.0
# 609       0        0           0          0              0           2900.0
# 132       1        0           0          0              0           2718.0
# ..      ...      ...         ...        ...            ...              ...
# 380       1        1           0          0              0           5833.0
# 446       1        1           2          1              0           4652.0
# 144       1        1           2          0              0          11757.0
# 290       1        1           0          0              0           5491.0
# 353       0        1           0          0              1           5500.0
#
# ...

# %%
y_test
# Out:
# 350    Y
# 377    Y
# 163    Y
# 609    Y
# 132    Y
#       ..
# 380    Y
# 446    Y
# 144    Y
# 290    Y
# 353    N
# Name: Loan_Status, Length: 185, dtype: object

# %%
from sklearn.linear_model import LogisticRegression

log=LogisticRegression(max_iter=2000)
log.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
y_pred_test=log.predict(X_test)

# %%
y_pred_test
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred_test)
# Out:
# 0.7837837837837838

# %%
# serialization and deserialization

import joblib

joblib.dump(log,"my_trained_model.pkl")
# Out:
# ['my_trained_model.pkl']

# %%
# deserialization  : it is opposite of serialization; means loading a file into a variable.
final_model=joblib.load("my_trained_model.pkl")

# %%
final_model
# Out:
# LogisticRegression(max_iter=2000)

# %%
import sys

# %%
sys.path
# Out:
# ['/usr/lib/python38.zip',
#  '/usr/lib/python3.8',
#  '/usr/lib/python3.8/lib-dynload',
#  '',
#  '/home/admin1/.local/lib/python3.8/site-packages',
#  '/usr/local/lib/python3.8/dist-packages',
#  '/usr/lib/python3/dist-packages']

# %%
import sys

# %%
sys.path
# Out:
# ['/usr/lib/python38.zip',
#  '/usr/lib/python3.8',
#  '/usr/lib/python3.8/lib-dynload',
#  '',
#  '/home/admin1/.local/lib/python3.8/site-packages',
#  '/usr/local/lib/python3.8/dist-packages',
#  '/usr/lib/python3/dist-packages']

# %%
from package_ml_model.package_ml import test

# %%
test.add(2,3)
# Out:
# 5

# %%
import pathlib
import package_ml
import os

PACKAGE_ROOT=pathlib.Path(package_ml.__file__).resolve().parent

print(PACKAGE_ROOT)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pathlib
# ----> 2 import package_ml
#       3 import os
#       5 PACKAGE_ROOT=pathlib.Path(package_ml.__file__).resolve().parent
#
# ModuleNotFoundError: No module named 'package_ml'
